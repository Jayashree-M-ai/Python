# %%
from classlib import manyfunctions

# %%
manyfunctions.subfields()
# Out:
# Sub-fields of AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
num=int(input("Enter the number"))
msg=manyfunctions.oddeven(num)
print(num," is a ", msg)
# Out:
# Enter the number 43
# 43  is a  Odd Number

# %%
gen=input("Enter the gender")
age=int(input("Enter the age"))
msg=manyfunctions.eligible(gen,age)
print("Your Gender:",gen,"\n Your Age:",age,"\n",msg)
# Out:
# Enter the gender female
# Enter the age 15
# Your Gender: female
#  Your Age: 15
#  Not Eligible

# %%
total,percentage=manyfunctions.per()
print("Total:",total,"\nPercentage:",percentage)
# Out:
# Enter the Subject 1 89
# Enter the Subject 2 98
# Enter the Subject 3 90
# Enter the Subject 4 97
# Enter the Subject 5 67
# Total: 441
# Percentage: 88.2

# %%
ar=manyfunctions.area()
print("Area of a Triangle=",ar)
pr=manyfunctions.peri()
print("Perimeter of a Triangle=",pr)
# Out:
# Enter Height 23
# Enter Breadth 32
# Area Formala:(Height*Breadth)/2
# Area of a Triangle= 368.0
# Enter Height1 5
# Enetr Height2 4
# Enter Breadth 3
# Perimeter formula: Height1 + Height2 + Breadth
# Perimeter of a Triangle= 12
