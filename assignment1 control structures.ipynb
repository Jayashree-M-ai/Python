# %%
print("Welcome to Assignment -1")
# Out:
# Welcome to Assignment -1

# %%
num1=10
num2=30
add=num1+num2
print("Num1=",num1,"\nNum2=",num2,"\nAdd=",add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
#Body Mass Index
bmi=float(input("Enter the BMI Index"))
if(bmi<18.5):
    print("Underweight")
elif(bmi<=24.5):
    print("Normal")
elif(bmi<=29.5):
    print("Overweight")
elif(bmi<=34.9):
    print("Very overweight or Obese")
else:
    print("Extremely Obese")
# Out:
# Enter the BMI Index 30
# Very overweight or Obese
