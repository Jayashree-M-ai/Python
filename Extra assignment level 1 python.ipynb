# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
ins_name=input("Enter your institute name:")
print("Your institute name:",ins_name)
# Out:
# Enter your institute name: Hope AI
# Your institute name: Hope AI

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
school=input("Enter your School name:")
degree=input("Enter your degree:")
print("Name=",name,"\nAge=",age,"\nSchool=",school,"\nDegree=",degree)
# Out:
# Enter your name: Jayashree
# Enter your age: 35
# Enter your School name: KRM
# Enter your degree: CS
# Name= Jayashree
# Age= 35
# School= KRM
# Degree= CS

# %%
a=43
b=34
add=a+b
print("a=",a,"\nb=",b,"\nAdd=",add)
# Out:
# a= 43
# b= 34
# Add= 77

# %%
sub=a-b
print("a=",a,"\nb=",b,"\nSub=",sub)
# Out:
# a= 43
# b= 34
# Sub= 9

# %%
a=63
b=97
mul=a*b
print("a=",a,"\nb=",b,"\nMul=",mul)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
a=76
b=31
div=a/b
print("a=",a,"\nb=",b,"\nFloat Div=",div)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
floor_div=a//b
print("a=",a,"\nb=",b,"\nFloor Div=",floor_div)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
mod=a%b
print("a=",a,"\nb=",b,"\nMod=",mod)
# Out:
# a= 76
# b= 31
# Mod= 14

# %%
a=4
b=4
power=a**b
print("a=",a,"\nb=",b,"\nPower=",power)
# Out:
# a= 4
# b= 4
# Power= 256
